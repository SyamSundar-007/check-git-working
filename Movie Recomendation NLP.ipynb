# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('movies_metadata.csv')

# %%
#  NLP workflow 

#  Find the useful cols for model creation

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  str
#  1   belongs_to_collection  4494 non-null   str
#  2   budget                 45466 non-null  str
#  3   genres                 45466 non-null  str
#  4   homepage               7782 non-null   str
#  5   id                     45466 non-null  str
#  6   imdb_id                45449 non-null  str
#  7   original_language      45455 non-null  str
#  8   original_title         45466 non-null  str
#  9   overview               44512 non-null  str
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  str
#  12  production_companies   45463 non-null  str
#  13  production_countries   45463 non-null  str
#  14  release_date           45379 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df['production_companies']
# Out:
# 0           [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1        [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3        [{'name': 'Twentieth Century Fox Film Corporat...
# 4        [{'name': 'Sandollar Productions', 'id': 5842}...
#                                ...
# 45461                                                   []
# 45462               [{'name': 'Sine Olivia', 'id': 19653}]
# 45463    [{'name': 'American World Pictures', 'id': 6165}]
# 45464                 [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                   []
# Name: production_companies, Length: 45466, dtype: str

# %%
df.duplicated().sum()

df = df.drop_duplicates().reset_index(drop=True)

# %%
required_cols = ['title','genres', 'overview','popularity', 'tagline','vote_average']

df_new = df[required_cols]

# %%
import ast

x = "[1, 2, 3, 4]"

# result = 

for i in ast.literal_eval(x):
    print(i)

# print( result)
# Out:
# 1
# 2
# 3
# 4

# %%
df_new.isnull().sum()

df_new['overview'] = df_new['overview'].fillna('')

# %%
#  extract genres from the text dict 
df_new['genres'] = df_new['genres'].apply( lambda x: " ".join( [  i['name'] for i in ast.literal_eval(x)   ] ))

# %%
df_new
# Out:
#                              title                    genres  \
# 0                        Toy Story   Animation Comedy Family
# 1                          Jumanji  Adventure Fantasy Family
# 2                 Grumpier Old Men            Romance Comedy
# 3                Waiting to Exhale      Comedy Drama Romance
# 4      Father of the Bride Part II                    Comedy
# ...                            ...                       ...
# 45448                       Subdue              Drama Family
# 45449          Century of Birthing                     Drama
# 45450                     Betrayal     Action Drama Thriller
# 45451             Satan Triumphant
# 45452                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# ...

# %%
df_new['tagline']= df_new['tagline'].fillna("")

# %%
df_new.isnull().sum()
# Out:
# title           6
# genres          0
# overview        0
# popularity      5
# tagline         0
# vote_average    6
# dtype: int64

# %%
df_new = df_new.dropna(subset=['title'])

# %%
df_new.isnull().sum()
# Out:
# title           0
# genres          0
# overview        0
# popularity      0
# tagline         0
# vote_average    0
# dtype: int64

# %%
df_new['tags'] = df_new['overview']+ " "+ df_new['genres']+" " + df_new['tagline']

# %%
df_new.head()
# Out:
#                          title                    genres  \
# 0                    Toy Story   Animation Comedy Family
# 1                      Jumanji  Adventure Fantasy Family
# 2             Grumpier Old Men            Romance Comedy
# 3            Waiting to Exhale      Comedy Drama Romance
# 4  Father of the Bride Part II                    Comedy
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                              tagline  vote_average  \
# 0                                                              7.7
# 1          Roll the dice and unleash the excitement!           6.9
# ...

# %%
#  Convert the text into  lower case 
#  Remove special characters like punctuations
#  remove stop words
#  lemetization ( converting the words to it's nearest dict meaning )
#  tokenize the words ( splits the text into words )
#  vectorizing ( converting the tokens into numeric format )

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Syam
# [nltk_data]     Sundar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Syam
# [nltk_data]     Sundar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Syam
# [nltk_data]     Sundar\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words =  set( stopwords.words('english'))
lemetizer = WordNetLemmatizer()

# %%
def preprocess_text(text):
    text = str(text.lower())
    text =  re.sub(r'[^\w\s]', "", text)
    words = text.split()
    words = [ word for word in words if word not in stop_words ]
    words = [ lemetizer.lemmatize(word)  for word in words ]
    return " ".join(words)

# %%
df_new['tags']= df_new['tags'].apply( preprocess_text)

# %%
#  Since we'll be using the cosine similarity algorithm we are going to need the indices so, we are creating a indicesabs

indices = pd.Series(df_new.index , index= df_new['title'])
indices
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Subdue                         45448
# Century of Birthing            45449
# Betrayal                       45450
# Satan Triumphant               45451
# Queerama                       45452
# Length: 45447, dtype: int64

# %%
df_new.head()
# Out:
#                          title                    genres  \
# 0                    Toy Story   Animation Comedy Family
# 1                      Jumanji  Adventure Fantasy Family
# 2             Grumpier Old Men            Romance Comedy
# 3            Waiting to Exhale      Comedy Drama Romance
# 4  Father of the Bride Part II                    Comedy
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                              tagline  vote_average  \
# 0                                                              7.7
# 1          Roll the dice and unleash the excitement!           6.9
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#  Here we are restricting the dictinary size to 50K so that the size stay same irrespective of word size
tfidf = TfidfVectorizer( max_features=50000, ngram_range= (1, 2,), stop_words= 'english')

tfidf_matrix = tfidf.fit_transform(df_new['tags'])

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1555624 stored elements and shape (45447, 50000)>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recomend_movie( title , n=10):
    if title not in indices:
        return['Movie not found']
    idx = indices[title]
    sim_score = cosine_similarity(tfidf_matrix[idx],tfidf_matrix ).flatten()
    similar_index = sim_score.argsort()[::-1][1:n+1]
    return df_new['title'].iloc[similar_index]

# %%
recomend_movie( 'Toy Story')
# Out:
# 2996                Toy Story 2
# 15344               Toy Story 3
# 24514                 Small Fry
# 28974           Superstar Goofy
# 17184                 Group Sex
# 6434     What's Up, Tiger Lily?
# 11396    For Your Consideration
# 1931                  Condorman
# 1071      Rebel Without a Cause
# 485                      Malice
# Name: title, dtype: str

# %% [markdown]
# #  _____________Till Here model creation is done _________________

# %%
#  let convert this model into a pickle file to use it in a real project

# %%
# import pickle

# pickle.dump(df_new, open('df_new.pkl', 'wb'))
# pickle.dump(tfidf , open('tfidf.pkl', 'wb'))
# pickle.dump(indices, open('indices.pkl', 'wb'))
# pickle.dump(tfidf_matrix, open('tfidf_matrix.pkl', 'wb') )
